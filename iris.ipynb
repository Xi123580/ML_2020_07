# %% [markdown]
# <a href="https://colab.research.google.com/github/text123580/ml20200716/blob/master/iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#! [驚嘆號 + 指令] 相當於Terminnal指令
# !python --version

# %%
import pandas as pd
from sklearn.datasets import load_iris
iris = load_iris()
df = pd.DataFrame(iris["data"], 
                  columns = iris["feature_names"]
)
df["answer"] = iris["target"]
df.to_csv("iris.csv", encoding = "utf8", index=False)
df

# %%
from sklearn.model_selection import train_test_split
# [90% data, 10% data, 90% target, 10% target]
x_train, x_test, y_train, y_test = train_test_split(iris["data"], 
                                                   iris["target"], 
                                                   test_size = 0.1)
# x_test

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth=2)
clf.fit(x_train, y_train)

# %%
import graphviz
from sklearn.tree import export_graphviz
g = export_graphviz(clf,
                    feature_names=iris["feature_names"],
                    class_names=iris["target_names"],
                    filled=True)
graphviz.Source(g)
# gini錯誤率係數
# entropy 對遞增/減函數取log[ *、/  ->  +、- ]

# %%
from sklearn.metrics import accuracy_score
pre = clf.predict(x_test)
accuracy_score(pre, y_test)
# 不可統計 問題訓練集-答案訓練集 必100%
# 過擬合--過度訓練 [勿訓練至完美[勿為了歧異點，導致背離常規]]
# 防止決策樹的過擬合方式
#   -前剪枝-設定最大深度
#   -後剪枝-拔掉看看
# Out:
# 0.9333333333333333
